# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fifa = pd.read_excel("FIFA-players_20.xlsx")

# %%
fifa
# Out:
#       sofifa_id                                         player_url  \
# 0        158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2        190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3        200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4        183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...         ...                                                ...
# 9174     223568  https://sofifa.com/player/223568/gjoko-zajkov/...
# 9175     223652  https://sofifa.com/player/223652/sebastian-ern...
# 9176     224095  https://sofifa.com/player/224095/nolan-mbemba/...
# 9177     224121  https://sofifa.com/player/224121/alessandro-ca...
# 9178     224324  https://sofifa.com/player/224324/oskar-zawada/...
#
#              short_name                            long_name  age        dob  \
# 0              L. Messi      Lionel AndrÃ©s Messi Cuccittini   32 1987-06-24
# ...

# %%
  for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
fifa.shape
# Out:
# (9179, 104)

# %%
9179*104
# Out:
# 954616

# %%
fifa['nationality'].value_counts() #nationality count
# Out:
# Spain             728
# Brazil            673
# Argentina         621
# Germany           557
# England           537
#                  ...
# Chad                1
# Bahrain             1
# St Kitts Nevis      1
# Eritrea             1
# Chinese Taipei      1
# Name: nationality, Length: 139, dtype: int64

# %%
fifa['nationality'].value_counts()[0:10] #top 10 nationality count
# Out:
# Spain          728
# Brazil         673
# Argentina      621
# Germany        557
# England        537
# France         535
# Italy          440
# Colombia       290
# Portugal       266
# Netherlands    253
# Name: nationality, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5]#top 5 nationality count
# Out:
# Spain        728
# Brazil       673
# Argentina    621
# Germany      557
# England      537
# Name: nationality, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5].keys()
# Out:
# Index(['Spain', 'Brazil', 'Argentina', 'Germany', 'England'], dtype='object')

# %%
plt.figure(figsize=(5,5))
plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()),list(fifa['nationality'].value_counts()[0:5]),color='r')
plt.show()

# %%
player_salary = fifa[['short_name','wage_eur']]
player_salary
# Out:
#              short_name  wage_eur
# 0              L. Messi    565000
# 1     Cristiano Ronaldo    405000
# 2             Neymar Jr    290000
# 3              J. Oblak    125000
# 4             E. Hazard    470000
# ...                 ...       ...
# 9174          G. Zajkov      4000
# 9175           S. Ernst      3000
# 9176          N. Mbemba      7000
# 9177         A. Capello      1000
# 9178          O. Zawada      2000
#
# [9179 rows x 2 columns]

# %%
player_salary = player_salary.sort_values(by=['wage_eur'],ascending=0)
player_salary
# Out:
#              short_name  wage_eur
# 0              L. Messi    565000
# 4             E. Hazard    470000
# 1     Cristiano Ronaldo    405000
# 5          K. De Bruyne    370000
# 22         A. Griezmann    370000
# ...                 ...       ...
# 5905           N. Dunga         0
# 4388            M. Alaa         0
# 6013          C. Comara         0
# 6052          A. Ghazal         0
# 2315         H. Lindner         0
#
# [9179 rows x 2 columns]

# %%
plt.figure(figsize=(8,5))
plt.bar(list(player_salary['short_name'])[0:5],list(player_salary['wage_eur'])[0:5],color=['orange','g','b','pink','r'])
plt.show()

# %%
fifa['nationlity']=='Germany'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9174    False
# 9175    False
# 9176    False
# 9177    False
# 9178    False
# Name: nationlity, Length: 9179, dtype: bool

# %%
Germany=fifa[fifa['nationality']=='Germany']
Germany.head(11)
# Out:
#      sofifa_id                                         player_url  \
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...
# 31      167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37      188350  https://sofifa.com/player/188350/marco-reus/20...
# 49      178603  https://sofifa.com/player/178603/mats-hummels/...
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 61      212622  https://sofifa.com/player/212622/joshua-kimmic...
# 70      189596  https://sofifa.com/player/189596/thomas-muller...
# 77      212190  https://sofifa.com/player/212190/niklas-sule/2...
# 109     235790  https://sofifa.com/player/235790/kai-havertz/2...
# 117     209658  https://sofifa.com/player/209658/leon-goretzka...
#
#         short_name               long_name  age        dob  height_cm  \
# 6    M. ter Stegen  Marc-AndrÃ© ter Stegen   27 1992-04-30        187
# ...

# %%
Germany.sort_values(by=['height_cm'],ascending=0)
# Out:
#       sofifa_id                                         player_url  \
# 8016     236831  https://sofifa.com/player/236831/aaron-seydel/...
# 1217     200212  https://sofifa.com/player/200212/michael-esser...
# 1389     199833  https://sofifa.com/player/199833/lars-unnersta...
# 4449     158657  https://sofifa.com/player/158657/thomas-kessle...
# 518      179783  https://sofifa.com/player/179783/ralf-fahrmann...
# ...         ...                                                ...
# 1098     203106  https://sofifa.com/player/203106/leonardo-bitt...
# 849      202325  https://sofifa.com/player/202325/diego-demme/2...
# 6222     234279  https://sofifa.com/player/234279/calogero-rizz...
# 1121     205966  https://sofifa.com/player/205966/amin-younes/2...
# 6364     189209  https://sofifa.com/player/189209/sascha-bigalk...
#
#           short_name             long_name  age        dob  height_cm  \
# 8016       A. Seydel          Aaron Seydel   23 1996-02-07        199
# ...

# %%
Germany.sort_values(by=['weight_kg'],ascending=0)
# Out:
#       sofifa_id                                         player_url  \
# 1389     199833  https://sofifa.com/player/199833/lars-unnersta...
# 518      179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 1217     200212  https://sofifa.com/player/200212/michael-esser...
# 77       212190  https://sofifa.com/player/212190/niklas-sule/2...
# 165      213331  https://sofifa.com/player/213331/jonathan-tah/...
# ...         ...                                                ...
# 5719     239696  https://sofifa.com/player/239696/florent-musli...
# 4788     235526  https://sofifa.com/player/235526/dennis-geiger...
# 5799     234385  https://sofifa.com/player/234385/niklas-hauptm...
# 1098     203106  https://sofifa.com/player/203106/leonardo-bitt...
# 6364     189209  https://sofifa.com/player/189209/sascha-bigalk...
#
#           short_name             long_name  age        dob  height_cm  \
# 1389   L. Unnerstall       Lars Unnerstall   28 1990-07-20        198
# ...

# %%
Germany.sort_values(by=['wage_eur'],ascending=0).head(10)
# Out:
#      sofifa_id                                         player_url  \
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 146     186942  https://sofifa.com/player/186942/ilkay-gundoga...
# 70      189596  https://sofifa.com/player/189596/thomas-muller...
# 37      188350  https://sofifa.com/player/188350/marco-reus/20...
# 31      167495  https://sofifa.com/player/167495/manuel-neuer/...
# 215     179846  https://sofifa.com/player/179846/sami-khedira/...
# 49      178603  https://sofifa.com/player/178603/mats-hummels/...
# 135     176635  https://sofifa.com/player/176635/mesut-ozil/20...
#
#         short_name               long_name  age        dob  height_cm  \
# 36        T. Kroos              Toni Kroos   29 1990-01-04        183
# 6    M. ter Stegen  Marc-AndrÃ© ter Stegen   27 1992-04-30        187
# ...

# %%
Germany[['short_name','wage_eur']].sort_values(by=['wage_eur'],ascending=0)
# Out:
#            short_name  wage_eur
# 36           T. Kroos    330000
# 6       M. ter Stegen    250000
# 55           L. SanÃ©    195000
# 146     I. GÃ¼ndoÄŸan    180000
# 70         T. MÃ¼ller    170000
# ...               ...       ...
# 8004  M. Christiansen      1000
# 387       B. HÃ¶wedes      1000
# 9124     M. SchrÃ¶ter      1000
# 8001        L. Boeder      1000
# 8395       M. Compper      1000
#
# [557 rows x 2 columns]

# %%
player_shooting = fifa[['short_name','shooting']]
player_shooting
# Out:
#              short_name  shooting
# 0              L. Messi      92.0
# 1     Cristiano Ronaldo      93.0
# 2             Neymar Jr      85.0
# 3              J. Oblak       NaN
# 4             E. Hazard      83.0
# ...                 ...       ...
# 9174          G. Zajkov      24.0
# 9175           S. Ernst      54.0
# 9176          N. Mbemba      59.0
# 9177         A. Capello      64.0
# 9178          O. Zawada      64.0
#
# [9179 rows x 2 columns]

# %%
player_shooting.sort_values(by=['shooting'],ascending=0)
# Out:
#              short_name  shooting
# 1     Cristiano Ronaldo      93.0
# 0              L. Messi      92.0
# 12              H. Kane      91.0
# 17           S. AgÃ¼ero      90.0
# 205     F. Quagliarella      89.0
# ...                 ...       ...
# 9143     D. StojanoviÄ‡       NaN
# 9149        N. Melissas       NaN
# 9151         I. LuÄiÄ‡       NaN
# 9159         A. Salazar       NaN
# 9166     Ãngel GalvÃ¡n       NaN
#
# [9179 rows x 2 columns]

# %%
player_defending= fifa[['short_name','defending','nationality','club']]
player_defending
# Out:
#              short_name  defending    nationality                   club
# 0              L. Messi       39.0      Argentina           FC Barcelona
# 1     Cristiano Ronaldo       35.0       Portugal               Juventus
# 2             Neymar Jr       32.0         Brazil    Paris Saint-Germain
# 3              J. Oblak        NaN       Slovenia       AtlÃ©tico Madrid
# 4             E. Hazard       35.0        Belgium            Real Madrid
# ...                 ...        ...            ...                    ...
# 9174          G. Zajkov       67.0  FYR Macedonia  Sporting de Charleroi
# 9175           S. Ernst       50.0        Germany  SpVgg Greuther FÃ¼rth
# 9176          N. Mbemba       60.0         France         Stade de Reims
# 9177         A. Capello       30.0          Italy             Venezia FC
# 9178          O. Zawada       26.0         Poland          WisÅ‚a PÅ‚ock
#
# [9179 rows x 4 columns]

# %%
player_defending.sort_values(by=['defending'],ascending=0)
# Out:
#           short_name  defending
# 7        V. van Dijk       90.0
# 16      G. Chiellini       90.0
# 11      K. Koulibaly       89.0
# 49        M. Hummels       89.0
# 35         D. GodÃ­n       89.0
# ...              ...        ...
# 9143  D. StojanoviÄ‡        NaN
# 9149     N. Melissas        NaN
# 9151      I. LuÄiÄ‡        NaN
# 9159      A. Salazar        NaN
# 9166  Ãngel GalvÃ¡n        NaN
#
# [9179 rows x 2 columns]

# %%
real_madrid=fifa[fifa['club']=='Real madrid']
real_madrid.head()
# Out:
# Empty DataFrame
# ...

# %%
real_madrid.sort_values(by=['wage_eur'],ascending=0)
# Out:
# Empty DataFrame
# ...

# %%
real_madrid.sort_values(by=['shooting'],ascending=0).head(5)
# Out:
# Empty DataFrame
# ...

# %%
real_madrid.sort_values(by=['defending'],ascending=0).head(5)
# Out:
# Empty DataFrame
# ...

# %%
real_madrid['nationality'].value_counts()
# Out:
# Series([], Name: nationality, dtype: int64)
